# %% [markdown]
# ### CSE-221710304057-T.Snithika Patel

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
boston_df = pd.DataFrame(boston.data,columns = boston.feature_names)
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
boston_df['MEDV'] = boston.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# ### Visualize all the input columns with the output column.Write your observations based on the plots generated, how the particular input is showing effect on the output

# %%
X = boston_df.drop(['MEDV'],axis=1)
y = boston_df['MEDV']

# %%
sns.regplot(boston_df.CRIM,boston_df.MEDV)

# %% [markdown]
# ### input column CRIM is weakly and negatively corelated with output column MEDV

# %% [markdown]
# ### So,it has minimal effect on output column

# %%
sns.regplot(boston_df.ZN,boston_df.MEDV)

# %% [markdown]
# ### input column ZN has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.INDUS,boston_df.MEDV)

# %% [markdown]
# ### input column INDUS has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.CHAS,boston_df.MEDV)

# %% [markdown]
# ### input column CHAS has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.NOX,boston_df.MEDV)

# %% [markdown]
# ### input column CHAS has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.RM,boston_df.MEDV)

# %% [markdown]
# ### input column RM has moderate positive corelation with the output column MEDV

# %% [markdown]
# ### So,it has moderate effect on the output column

# %%
sns.regplot(boston_df.AGE,boston_df.MEDV)

# %% [markdown]
# ### input column AGE has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.DIS,boston_df.MEDV)

# %% [markdown]
# ### input column DIS has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.RAD,boston_df.MEDV)

# %% [markdown]
# ### input column RAD has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.TAX,boston_df.MEDV)

# %% [markdown]
# ### input column TAX has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.PTRATIO,boston_df.MEDV)

# %% [markdown]
# ### input column PTRATIO has moderate negative corelation with the output column MEDV

# %% [markdown]
# ### So,it has moderate effect on the output column

# %%
sns.regplot(boston_df.B,boston_df.MEDV)

# %% [markdown]
# ###  input column B has no corelation with the output column MEDV

# %% [markdown]
# ### So,it has no effect on the output column

# %%
sns.regplot(boston_df.LSTAT,boston_df.MEDV)

# %% [markdown]
# ### input column LSTAT has moderately negative corelation with the output column MEDV

# %% [markdown]
# ### So,it has moderate effect on the output column

# %% [markdown]
# ### Remove any of the one variable from the dataset if correlation is greater than 0.9.
#     -Example: (X1 and X2 are highly correlated to each other.
#     -Correlation value between X1 and X2 is 0.92, then drop X1 or X2)

# %%
boston_df.corr()[boston_df.corr()>0.9]
# Out:
#          CRIM   ZN  INDUS  CHAS  NOX   RM  AGE  DIS       RAD       TAX  \
# CRIM      1.0  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# ZN        NaN  1.0    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# INDUS     NaN  NaN    1.0   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# CHAS      NaN  NaN    NaN   1.0  NaN  NaN  NaN  NaN       NaN       NaN
# NOX       NaN  NaN    NaN   NaN  1.0  NaN  NaN  NaN       NaN       NaN
# RM        NaN  NaN    NaN   NaN  NaN  1.0  NaN  NaN       NaN       NaN
# AGE       NaN  NaN    NaN   NaN  NaN  NaN  1.0  NaN       NaN       NaN
# DIS       NaN  NaN    NaN   NaN  NaN  NaN  NaN  1.0       NaN       NaN
# RAD       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  1.000000  0.910228
# TAX       NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN  0.910228  1.000000
# PTRATIO   NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# B         NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# LSTAT     NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
# MEDV      NaN  NaN    NaN   NaN  NaN  NaN  NaN  NaN       NaN       NaN
#
#          PTRATIO    B  LSTAT  MEDV
# CRIM         NaN  NaN    NaN   NaN
# ZN           NaN  NaN    NaN   NaN
# INDUS        NaN  NaN    NaN   NaN
# CHAS         NaN  NaN    NaN   NaN
# NOX          NaN  NaN    NaN   NaN
# RM           NaN  NaN    NaN   NaN
# AGE          NaN  NaN    NaN   NaN
# DIS          NaN  NaN    NaN   NaN
# RAD          NaN  NaN    NaN   NaN
# TAX          NaN  NaN    NaN   NaN
# PTRATIO      1.0  NaN    NaN   NaN
# B            NaN  1.0    NaN   NaN
# LSTAT        NaN  NaN    1.0   NaN
# MEDV         NaN  NaN    NaN   1.0

# %%
boston_df.drop('TAX',axis=1,inplace=True)

# %%
boston_df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  PTRATIO  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0     15.3
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0     17.8
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0     17.8
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0     18.7
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0     18.7
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0     18.7
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0     15.2
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0     15.2
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0     15.2
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0     15.2
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0     15.2
# 11    0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0     15.2
# 12    0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509   5.0     15.2
# 13    0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075   4.0     21.0
# 14    0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619   4.0     21.0
# 15    0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986   4.0     21.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986   4.0     21.0
# 17    0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579   4.0     21.0
# 18    0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965   4.0     21.0
# 19    0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965   4.0     21.0
# 20    1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979   4.0     21.0
# 21    0.85204   0.0   8.14   0.0  0.538  5.965   89.2  4.0123   4.0     21.0
# 22    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0     21.0
# 23    0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0     21.0
# 24    0.75026   0.0   8.14   0.0  0.538  5.924   94.1  4.3996   4.0     21.0
# 25    0.84054   0.0   8.14   0.0  0.538  5.599   85.7  4.4546   4.0     21.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813   90.3  4.6820   4.0     21.0
# 27    0.95577   0.0   8.14   0.0  0.538  6.047   88.8  4.4534   4.0     21.0
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547   4.0     21.0
# 29    1.00245   0.0   8.14   0.0  0.538  6.674   87.3  4.2390   4.0     21.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...      ...
# 476   4.87141   0.0  18.10   0.0  0.614  6.484   93.6  2.3053  24.0     20.2
# 477  15.02340   0.0  18.10   0.0  0.614  5.304   97.3  2.1007  24.0     20.2
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705  24.0     20.2
# 479  14.33370   0.0  18.10   0.0  0.614  6.229   88.0  1.9512  24.0     20.2
# 480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  24.0     20.2
# 481   5.70818   0.0  18.10   0.0  0.532  6.750   74.9  3.3317  24.0     20.2
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0     20.2
# 483   2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  24.0     20.2
# 484   2.37857   0.0  18.10   0.0  0.583  5.871   41.9  3.7240  24.0     20.2
# 485   3.67367   0.0  18.10   0.0  0.583  6.312   51.9  3.9917  24.0     20.2
# 486   5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5459  24.0     20.2
# 487   4.83567   0.0  18.10   0.0  0.583  5.905   53.2  3.1523  24.0     20.2
# 488   0.15086   0.0  27.74   0.0  0.609  5.454   92.7  1.8209   4.0     20.1
# 489   0.18337   0.0  27.74   0.0  0.609  5.414   98.3  1.7554   4.0     20.1
# 490   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226   4.0     20.1
# 491   0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0     20.1
# 492   0.11132   0.0  27.74   0.0  0.609  5.983   83.5  2.1099   4.0     20.1
# 493   0.17331   0.0   9.69   0.0  0.585  5.707   54.0  2.3817   6.0     19.2
# 494   0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817   6.0     19.2
# 495   0.17899   0.0   9.69   0.0  0.585  5.670   28.8  2.7986   6.0     19.2
# 496   0.28960   0.0   9.69   0.0  0.585  5.390   72.9  2.7986   6.0     19.2
# 497   0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927   6.0     19.2
# 498   0.23912   0.0   9.69   0.0  0.585  6.019   65.3  2.4091   6.0     19.2
# 499   0.17783   0.0   9.69   0.0  0.585  5.569   73.5  2.3999   6.0     19.2
# 500   0.22438   0.0   9.69   0.0  0.585  6.027   79.7  2.4982   6.0     19.2
# 501   0.06263   0.0  11.93   0.0  0.573  6.593   69.1  2.4786   1.0     21.0
# 502   0.04527   0.0  11.93   0.0  0.573  6.120   76.7  2.2875   1.0     21.0
# 503   0.06076   0.0  11.93   0.0  0.573  6.976   91.0  2.1675   1.0     21.0
# 504   0.10959   0.0  11.93   0.0  0.573  6.794   89.3  2.3889   1.0     21.0
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   80.8  2.5050   1.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# 5    394.12   5.21  28.7
# 6    395.60  12.43  22.9
# 7    396.90  19.15  27.1
# 8    386.63  29.93  16.5
# 9    386.71  17.10  18.9
# 10   392.52  20.45  15.0
# 11   396.90  13.27  18.9
# 12   390.50  15.71  21.7
# 13   396.90   8.26  20.4
# 14   380.02  10.26  18.2
# 15   395.62   8.47  19.9
# 16   386.85   6.58  23.1
# 17   386.75  14.67  17.5
# 18   288.99  11.69  20.2
# 19   390.95  11.28  18.2
# 20   376.57  21.02  13.6
# 21   392.53  13.83  19.6
# 22   396.90  18.72  15.2
# 23   394.54  19.88  14.5
# 24   394.33  16.30  15.6
# 25   303.42  16.51  13.9
# 26   376.88  14.81  16.6
# 27   306.38  17.28  14.8
# 28   387.94  12.80  18.4
# 29   380.23  11.98  21.0
# ..      ...    ...   ...
# 476  396.21  18.68  16.7
# 477  349.48  24.91  12.0
# 478  379.70  18.03  14.6
# 479  383.32  13.11  21.4
# 480  396.90  10.74  23.0
# 481  393.07   7.74  23.7
# 482  395.28   7.01  25.0
# 483  392.92  10.42  21.8
# 484  370.73  13.34  20.6
# 485  388.62  10.58  21.2
# 486  392.68  14.98  19.1
# 487  388.22  11.45  20.6
# 488  395.09  18.06  15.2
# 489  344.05  23.97   7.0
# 490  318.43  29.68   8.1
# 491  390.11  18.07  13.6
# 492  396.90  13.35  20.1
# 493  396.90  12.01  21.8
# 494  396.90  13.59  24.5
# 495  393.29  17.60  23.1
# 496  396.90  21.14  19.7
# 497  396.90  14.10  18.3
# 498  396.90  12.92  21.2
# 499  395.77  15.10  17.5
# 500  396.90  14.33  16.8
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# ### Split the data into training and test with a split ratio of 80-20(80% of the data into training data and 20% of the data into testing)

# %%
from sklearn.model_selection import train_test_split
X = boston_df.drop('MEDV',axis=1)
y = boston_df['MEDV']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print('X_train: ',X_train.shape)
print('X_test: ',X_test.shape)
print('y_train: ',y_train.shape)
print('y_test: ',y_test.shape)
# Out:
# X_train:  (404, 12)
# X_test:  (102, 12)
# y_train:  (404,)
# y_test:  (102,)

# %% [markdown]
# ### Apply feature scaling on the input columns, and build the Multiple Linear Regression Model. Check the performance on training and testing. Write your inferences on performance metrics and error metrics.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
boston_df_scaled=pd.DataFrame(data=sc.fit_transform(boston_df),columns=boston_df.columns)
boston_df_scaled
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# 5   -0.417044 -0.487722 -1.306878 -0.272599 -0.835284  0.207096 -0.351157
# 6   -0.410243  0.048772 -0.476654 -0.272599 -0.265154 -0.388411 -0.070229
# 7   -0.403696  0.048772 -0.476654 -0.272599 -0.265154 -0.160466  0.978808
# 8   -0.395935  0.048772 -0.476654 -0.272599 -0.265154 -0.931206  1.117494
# 9   -0.400729  0.048772 -0.476654 -0.272599 -0.265154 -0.399808  0.616090
# 10  -0.394346  0.048772 -0.476654 -0.272599 -0.265154  0.131589  0.914799
# 11  -0.406847  0.048772 -0.476654 -0.272599 -0.265154 -0.392685  0.509409
# 12  -0.409604  0.048772 -0.476654 -0.272599 -0.265154 -0.563644 -1.051700
# 13  -0.347230 -0.487722 -0.437258 -0.272599 -0.144217 -0.478164 -0.240919
# 14  -0.346276 -0.487722 -0.437258 -0.272599 -0.144217 -0.268740  0.566306
# 15  -0.347506 -0.487722 -0.437258 -0.272599 -0.144217 -0.642000 -0.429390
# 16  -0.297868 -0.487722 -0.437258 -0.272599 -0.144217 -0.498110 -1.396638
# 17  -0.329258 -0.487722 -0.437258 -0.272599 -0.144217 -0.419753  0.466736
# 18  -0.327103 -0.487722 -0.437258 -0.272599 -0.144217 -1.180521 -1.137046
# 19  -0.336054 -0.487722 -0.437258 -0.272599 -0.144217 -0.794439  0.032897
# 20  -0.274843 -0.487722 -0.437258 -0.272599 -0.144217 -1.018110  1.049929
# 21  -0.321363 -0.487722 -0.437258 -0.272599 -0.144217 -0.455370  0.733440
# 22  -0.277091 -0.487722 -0.437258 -0.272599 -0.144217 -0.203205  0.822342
# 23  -0.305491 -0.487722 -0.437258 -0.272599 -0.144217 -0.671918  1.117494
# 487 -0.305540  1.661245  0.806576  0.345881 -0.168638 -0.210362
# 488 -0.938447 -0.637962  0.760340  0.421206  0.757911 -0.798084
# 489 -0.969583 -0.637962  0.760340 -0.138414  1.586338 -1.690551
# 490 -0.937638 -0.637962  0.760340 -0.419321  2.386730 -1.570830
# 491 -0.916009 -0.637962  0.760340  0.366604  0.759313 -0.972224
# 492 -0.801065 -0.637962  0.760340  0.441052  0.097692 -0.264781
# 493 -0.671859 -0.408041  0.344213  0.441052 -0.090141 -0.079757
# 494 -0.671859 -0.408041  0.344213  0.441052  0.131334  0.214104
# 495 -0.473678 -0.408041  0.344213  0.401471  0.693431  0.061732
# 496 -0.473678 -0.408041  0.344213  0.441052  1.189646 -0.308315
# 497 -0.428946 -0.408041  0.344213  0.441052  0.202823 -0.460688
# 498 -0.658834 -0.408041  0.344213  0.441052  0.037418 -0.145059
# 499 -0.663208 -0.408041  0.344213  0.428662  0.342996 -0.547758
# 500 -0.616479 -0.408041  0.344213  0.441052  0.235063 -0.623944
# 501 -0.625796 -0.982843  1.176466  0.387217 -0.418147 -0.014454
# 502 -0.716639 -0.982843  1.176466  0.441052 -0.500850 -0.210362
# 503 -0.773684 -0.982843  1.176466  0.441052 -0.983048  0.148802
# 504 -0.668437 -0.982843  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.982843  1.176466  0.441052 -0.669058 -1.157248
#
# [506 rows x 13 columns]

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)

# %%
y_train_pred
# Out:
# array([32.60860292, 21.89041483, 27.48990674, 23.6066335 ,  6.50781959,
#        14.76466875, 21.98310866, 29.14051313, 33.39245807, 13.15969473,
#        20.26682717, 21.69822419, 12.63458758, 23.27598101,  4.99773457,
#        20.07544365,  9.30657192, 44.52460572, 31.97176274, 12.4375555 ,
#        17.30860044, 21.92619055, 23.52476909, 18.00805609, 34.07974181,
#        13.76233325, 20.33716573, 34.96866337, 19.43413344, 13.22440184,
#        16.90178472, 23.17568479, 14.41724798, 30.33783949, 25.000865  ,
#        15.56127428, 24.25972035,  9.43336089, 14.99632788, 21.36891995,
#        32.34259934, 27.57553221, 26.30210232, 15.54966886, 32.40953364,
#        27.93487003, 13.9909288 ,  7.56313803, 28.37666182, 25.22808173,
#         4.70164763, 27.73023761, 17.44835701, 30.38205417, 18.03885333,
#        15.95451226, 18.53436436, 12.70329919,  8.6893254 , 19.21475535,
#        33.93411833, 32.7478776 , 23.52123884, 19.3686706 , 22.62745897,
#        26.84400741, 21.72337128, 17.01846422, 32.31512887, 10.90337258,
#        19.41077376, 32.86811027, 18.90040481, 15.97684267, 19.12247397,
#        14.92737471, 24.73086063, 23.84198343, 16.61465062, 13.33495946,
#        19.44016838, 25.19951569, 17.84944705, 24.56855828, 21.92736845,
#        27.75423539, 35.34296107, 16.61147937, 11.7962077 , 34.64860386,
#        31.37978104, 20.60046379, 39.4541041 , 27.90920858, 29.1125036 ,
#        17.36431499, 26.74131683, 39.79061041, 27.72050079, 16.42838683,
#        37.26781576, 36.39542326, 13.35272216, 29.2159196 , 21.49407308,
#        41.20551006, 24.94134248, 19.87782008, 15.01858502, 11.95919184,
#        14.11058804, 18.48415131,  2.90410592, 27.97294904, 26.04839353,
#        41.01848618, 22.09715049, 21.34919686, 33.23279581, 32.75221188,
#         9.6866879 , 24.56189213, 43.30454651, 17.02031093, 17.8707688 ,
#        25.18940898, 19.09582825,  6.00758324, 19.39970582, 34.67912158,
#        16.2229207 , 22.8709488 , 13.47638391, 24.07834611, 18.74283404,
#        17.29928424, 19.03950777, 32.25742409, 19.50757407, 30.26112157,
#        33.12183178, 41.89294634, 18.95193114, 16.4739003 , 38.56041972,
#        17.98398671,  9.47515055, 15.36167608, 24.47337717, 19.76237957,
#        16.60493377, 27.02539564, 12.99817126,  5.81757267, 18.99448216,
#         9.67478291, 28.83978735,  7.29157876, 29.42751698, 32.88700961,
#        21.40614806, 16.73838432, 18.20862676, 19.95937976, 34.48002336,
#        27.68731522, 19.55554752, 21.72568811,  6.65562971, 28.56996559,
#        24.58457987, 21.43316229, 13.61400719, 25.87405121, 18.56444763,
#        11.61625126, 26.89875889, 18.99686102, 30.94440477, 32.91433112,
#        25.3857394 , 18.53587083, 31.10628329, 21.66263005, 25.28283823,
#        25.87617931, 30.72482752, 24.40328136, 34.23768419, 16.95784987,
#        19.69812536, 18.44862361, 40.83918815, 25.14023491, 19.24195273,
#        34.55725439, 24.79295057, 18.08495273, 23.42145781])

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('Train :')

print('R^2:', r2_score(y_train,y_train_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_train, y_train_pred))*(len(X_train)-1)/
      (len(X_train)-X_train.shape[1]-1))
print('MAE: ',mean_absolute_error(y_train,y_train_pred))
print('MSE: ',mean_squared_error(y_train,y_train_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_train,y_train_pred)))

print('Test :')

print('R^2:', r2_score(y_test,y_test_pred)) 
print('Adjusted R^2:', 1- (1-r2_score(y_test, y_test_pred))*(len(X_test)-1)/
      (len(X_test)-X_test.shape[1]-1))
print('MAE: ',mean_absolute_error(y_test,y_test_pred))
print('MSE ',mean_squared_error(y_test,y_test_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,y_test_pred)))
# Out:
# Train :
# R^2: 0.7683881100856012
# Adjusted R^2: 0.7612798167889956
# MAE:  3.1292635145618504
# MSE:  19.720297955309395
# RMSE:  4.440754210188782
# Test :
# R^2: 0.5779801896440161
# Adjusted R^2: 0.5210786421802879
# MAE:  3.9528873361338235
# MSE  34.36441441048652
# RMSE:  5.862116888163056

# %% [markdown]
# ### Performance Metrics:

# %% [markdown]
# ### Training
#     -R2: it indicates 74% accuracy
#     -adjusted R2: indicates 73% accuracy

# %% [markdown]
# ### Testing
#     -The RMSE is 4.46, indicating an error of +/- 4.6 in the predicted values
#     -The accuracy of the model on predicting the trained data is around 73% and the error caused while predicting these values is around 4.46

# %% [markdown]
# ### Error Metrics:

# %% [markdown]
# ### Training
#     -R2: it indicates 69% accuracy
#     -adjusted R2: indicates 64% accuracy

# %% [markdown]
# ### Testing
#     -The RMSE is 5.86, indicating an error of +/- 5.86 in the predicted values
#     -The accuracy of the model on predicting the trained data is around 69% and the error caused while predicting these values is around 5.8
