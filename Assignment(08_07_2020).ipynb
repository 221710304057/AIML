# %% [markdown]
# **CSE-221710304057-T.Snithika Patel**

# %%
#net h1 = w1*i1+w2*i2+b1*1
0.15*0.05+0.2*0.1+0.35*1
# Out:
# 0.3775

# %% [markdown]
# The output for h1: The output for h1 is calculated by applying sigmoid function to the net input Of h1. The sigmoid function pumps the values for which it is used in the range, 0 to 1.
#
# It is used for models where we have to predict the probability. Since the probability of any event lies between 0 and 1, the sigmoid function is the right choice.
#
# out h1 = 1/(1+e-0.3775) --> 0.5932
#
# Carrying out the same process for h2
#
# out h2 = 0.596
#
# The output for o1: net o1 = w5out h1 + w6outh2 + b2*1

# %%
0.4*0.593+0.45*0.596+0.6*1  #net o1
# Out:
# 1.1054

# %% [markdown]
# out o1 = 1/(1+e^-1.1054) --> 0.751
#
# Carrying out the same process for o2
#
# out o2 = 0.7729

# %% [markdown]
# Read an image(which contains different objects) using matplotlib and check the shape of the image?
#
# Display the image?
#
# Identify the different objects in the image?
#
# Use slicing to get the objects and display them?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("/content/drive/My Drive/Summer Internship/mickey-mouse.jpg")
print(img.shape)
# Out:
# (720, 1280, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,0:200])

# %%
plt.imshow(img[:400,:400])

# %%
plt.imshow(img[0:300,0:150]) #slide

# %%
plt.imshow(img[50:700,450:1050]) #Mickey mouse and Minnie mouse
